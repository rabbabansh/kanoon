# %%
# load data
import os
import shutil
import PyPDF2
import spacy
from pathlib import Path

# %%
# embeddings
import numpy as np
import pandas as pd

# %%
#Load spacy English Corpus
# !python -m spacy download en_core_web_sm -q
nlp = spacy.load('en_core_web_sm')
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Initialize lists for documents, metadatas, and ids
documents = []
metadatas = []
ids = []

# %%
# Ensure the destination folder /pdfID exists
destination_folder = '../data/out/pdfIDs'
Path(destination_folder).mkdir(parents=True, exist_ok=True)

# %%
# Function to process each PDF file
def process_pdf(pdf_path, pdfID):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        num_pages = len(reader.pages)
        list_of_pages = [] # List of pages as strings
        
        for i in range(num_pages):
            page_text = reader.pages[i].extract_text()
            list_of_pages.append(page_text)
            
            # Split page into sentences using spacy
            sentences_from_page = [sent.text for sent in nlp(page_text).sents]
            
            for sentenceID, sentence in enumerate(sentences_from_page):
                documents.append(sentence)
                metadatas.append({"pageID": str(i), "pdfID": str(pdfID)})
                ids.append(f"{pdfID}-{i}-{sentenceID}")
    
    return list_of_pages

# %%
# Iterate through PDF files in /sample_data and process them
source_folder = "../data/source"
pdf_files = [f for f in os.listdir(source_folder) if f.endswith('.pdf') or f.endswith('.PDF')]

for pdfID, pdf_file in enumerate(pdf_files):
    # Process each PDF
    pdf_path = os.path.join(source_folder, pdf_file)
    list_of_pages = process_pdf(pdf_path, pdfID)
    
    # Copy and rename the PDF to /pdfID folder
    destination_path = os.path.join(destination_folder, f"{pdfID}.pdf")
    shutil.copy(pdf_path, destination_path)

# %%
# Create a dataframe
df = pd.DataFrame({"id": ids, "text": documents, "metadata": metadatas})
df.to_csv('../data/out/pdf_data.csv', index=False)
df.head(50)
# Out:
#         id                                               text  \
# 0    0-0-0                              Allauddin Mian & Ors.
# 1    0-0-1  Sharif Mian & Anr vs State Of Bihar on 13\nApr...
# 2    0-0-2  A.M. Ahmadi\n           PETITIONER:\nALLAUDDIN...
# 3    0-0-3                       SHARIF MIAN & ANR.\n
# 4    0-0-4                                                 Vs
# 5    0-0-5                                   .\nRESPONDENT:\n
# 6    0-0-6  STATE OF BIHAR\nDATE OF JUDGMENT13/04/1989\nBE...
# 7    0-0-7  Section   235   and\nsection   354(3)--Sentenc...
# 8    0-0-8                           Indian Penal Code, 1860:
# 9    0-0-9  Sections 34, 141, 149--Unlawful\nassembly--Fas...
# 10  0-0-10          Baharan Mian, appre-Allauddin Mian & Ors.
# 11  0-0-11  Sharif Mian & Anr vs State Of Bihar on 13 Apri...
# 12   0-1-0  hending  trouble,  ran inside Co arm himself  ...
# 13   0-1-1  At that time,  Baharan\nMian's two infant daug...
# 14   0-1-2  Failing in their object to kill\nBaharan  Mlan...
# 15   0-1-3  As a result of these injuries,  Sahana\nKhatoo...
# 16   0-1-4  Accused Nos.1 and 2 were charged under section...
# 17   0-1-5  Accused Nos. 5 and 6 were  convicted  under\ns...
# 18   0-1-6  The  High Court dismissed the appeal of accuse...
# 19   0-1-7  The conviction of the remaining four  accused\...
# 20   0-1-8  Their convictions  and  sen-\ntences on the ot...
# 21   0-1-9  P.C.  was not followed in letter and  spirit; ...
# 22  0-1-10  While  partly  allowing the appeals  by  conve...
# 23  0-1-11  1 and  2  to\nimprisonment for life under sect...
# 24  0-1-12  Sharif Mian & Anr vs State Of Bihar on 13 Apri...
# 25   0-2-0              aside  the conviction of accused nos.
# 26   0-2-1  3 to 6  under  section\n326/149 I.P.C., the Co...
# 27   0-2-2  [508B-C]\n    (2) If the prosecution did not e...
# 28   0-2-3  The  non-\nexamination  of  these persons cann...
# 29   0-2-4                      [508F]\n    (3)  Section 149.
# 30   0-2-5           I.P.C., creates a.  specific  offence.\n
# 31   0-2-6  Since  this section imposes a constructive pen...
# 32   0-2-7  [509G]\n500\n    (4) It is not the intention o...
# 33   0-2-8  In order to invoke section  149  it\nmust be s...
# 34   0-2-9  Even if an\nact  incidental to the common obje...
# 35  0-2-10  If the  mem-\nbers of the assembly knew or wer...
# 36  0-2-11  prosecution of  the\ncommon  object they would...
# 37  0-2-12  I.P.C. [510F-H]\n    (5) What is important in ...
# 38  0-2-13  There  must be a nexus  between  the  common\n...
# 39  0-2-14  [509H; 510A-B]\n    (6) In the instant case, t...
# 40  0-2-15  When accused Nos. 1 and 2 realised that Bahara...
# 41  0-2-16                                              they.
# 42  0-2-17  frustrated at their failure to\naccomplish  th...
# 43  0-2-18  For accomplishing their common object\nit  was...
# 44  0-2-19  Accused Nos. 3 to 6 cannot,  therefore,  be\nc...
# 45  0-2-20  [511A-B]\n    (7) Section 302, I.P.C, casts a ...
# 46  0-2-21  When  the\nCourt is called upon to choose betw...
# 47  0-2-22  Sharif Mian & Anr vs State Of Bihar on 13 Apri...
# 48   0-3-0  want  to live' and the prosecutor's demand 'he...
# 49   0-3-1                                [511D-E]\n    (8)
#
#                          metadata
# 0   {'pageID': '0', 'pdfID': '0'}
# 1   {'pageID': '0', 'pdfID': '0'}
# 2   {'pageID': '0', 'pdfID': '0'}
# 3   {'pageID': '0', 'pdfID': '0'}
# 4   {'pageID': '0', 'pdfID': '0'}
# 5   {'pageID': '0', 'pdfID': '0'}
# 6   {'pageID': '0', 'pdfID': '0'}
# 7   {'pageID': '0', 'pdfID': '0'}
# 8   {'pageID': '0', 'pdfID': '0'}
# 9   {'pageID': '0', 'pdfID': '0'}
# 10  {'pageID': '0', 'pdfID': '0'}
# 11  {'pageID': '0', 'pdfID': '0'}
# 12  {'pageID': '1', 'pdfID': '0'}
# 13  {'pageID': '1', 'pdfID': '0'}
# 14  {'pageID': '1', 'pdfID': '0'}
# 15  {'pageID': '1', 'pdfID': '0'}
# 16  {'pageID': '1', 'pdfID': '0'}
# 17  {'pageID': '1', 'pdfID': '0'}
# 18  {'pageID': '1', 'pdfID': '0'}
# 19  {'pageID': '1', 'pdfID': '0'}
# 20  {'pageID': '1', 'pdfID': '0'}
# 21  {'pageID': '1', 'pdfID': '0'}
# 22  {'pageID': '1', 'pdfID': '0'}
# 23  {'pageID': '1', 'pdfID': '0'}
# 24  {'pageID': '1', 'pdfID': '0'}
# 25  {'pageID': '2', 'pdfID': '0'}
# 26  {'pageID': '2', 'pdfID': '0'}
# 27  {'pageID': '2', 'pdfID': '0'}
# 28  {'pageID': '2', 'pdfID': '0'}
# 29  {'pageID': '2', 'pdfID': '0'}
# 30  {'pageID': '2', 'pdfID': '0'}
# 31  {'pageID': '2', 'pdfID': '0'}
# 32  {'pageID': '2', 'pdfID': '0'}
# 33  {'pageID': '2', 'pdfID': '0'}
# 34  {'pageID': '2', 'pdfID': '0'}
# 35  {'pageID': '2', 'pdfID': '0'}
# 36  {'pageID': '2', 'pdfID': '0'}
# 37  {'pageID': '2', 'pdfID': '0'}
# 38  {'pageID': '2', 'pdfID': '0'}
# 39  {'pageID': '2', 'pdfID': '0'}
# 40  {'pageID': '2', 'pdfID': '0'}
# 41  {'pageID': '2', 'pdfID': '0'}
# 42  {'pageID': '2', 'pdfID': '0'}
# 43  {'pageID': '2', 'pdfID': '0'}
# 44  {'pageID': '2', 'pdfID': '0'}
# 45  {'pageID': '2', 'pdfID': '0'}
# 46  {'pageID': '2', 'pdfID': '0'}
# 47  {'pageID': '2', 'pdfID': '0'}
# 48  {'pageID': '3', 'pdfID': '0'}
# 49  {'pageID': '3', 'pdfID': '0'}
