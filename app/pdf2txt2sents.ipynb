# %%
# load data
import os
import shutil
import PyPDF2
import spacy
from pathlib import Path

# %%
# embeddings
import numpy as np
import pandas as pd

# %%
#Load spacy English Corpus
# !python -m spacy download en_core_web_sm -q
nlp = spacy.load('en_core_web_sm')
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Initialize lists for documents, metadatas, and ids
documents = []
metadatas = []
ids = []

# %%
# Ensure the destination folder /pdfID exists
destination_folder = '../data/out/pdfIDs'
Path(destination_folder).mkdir(parents=True, exist_ok=True)

# %%
# Function to process each PDF file
def process_pdf(pdf_path, pdfID):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        num_pages = len(reader.pages)
        list_of_pages = [] # List of pages as strings
        
        for i in range(num_pages):
            page_text = reader.pages[i].extract_text()
            list_of_pages.append(page_text)
            
            # Split page into sentences using spacy
            sentences_from_page = [sent.text for sent in nlp(page_text).sents]
            
            for sentenceID, sentence in enumerate(sentences_from_page):
                documents.append(sentence)
                metadatas.append({"pageID": str(i), "pdfID": str(pdfID)})
                ids.append(f"{pdfID}-{i}-{sentenceID}")
    
    return list_of_pages

# %%
# Iterate through PDF files in /sample_data and process them
source_folder = "../data/source"
pdf_files = [f for f in os.listdir(source_folder) if f.endswith('.pdf') or f.endswith('.PDF')]

for pdfID, pdf_file in enumerate(pdf_files):
    # Process each PDF
    pdf_path = os.path.join(source_folder, pdf_file)
    list_of_pages = process_pdf(pdf_path, pdfID)
    
    # Copy and rename the PDF to /pdfID folder
    destination_path = os.path.join(destination_folder, f"{pdfID}.pdf")
    shutil.copy(pdf_path, destination_path)

# %%
# Create a dataframe
df = pd.DataFrame({"id": ids, "text": documents, "metadata": metadatas})
df.to_csv('../data/out/pdf_data.csv', index=False)
df.head(50)
# Out:
#        id                                               text  \
# 0   0-0-0  IN THE HIGH COURT OF KERALA AT ERNAKULAM\nPRES...
# 1   0-0-1  NO. 970 OF 2022\nPETITIONERS:\n1DR.VIJIL,\nAGE...
# 2   0-0-2  2DR.SONIA, \nSM HOSPITAL, THANA, \nKANNUR, PIN...
# 3   0-0-3  3DR.B.V.BHAT, M/S. ASHOKA HOSPITAL, \nSOUTH BA...
# 4   0-0-4  4DR.ASHOK RAJ, \nJYOTHIS HOSPITAL, PALLIKUNNU,...
# 5   0-0-5  6DR.SUCHITHARA BHAT,\nASHOKA HOSPITAL, SOUTH B...
# 6   0-0-6               BY ADVS.\nS.GOPAKUMARAN NAIR (SR.)\n
# 7   0-0-7  SOORAJ T.ELENJICKAL\nRENOY VINCENT\nARUN ROY\n...
# 8   0-1-0         W.P.(C) No.970/2022\n: 2 :\nRESPONDENTS:\n
# 9   0-1-1  1AMBUJAKSHI .T.P.,\nW/O.JANARDHANAN, CHANDROTH...
# 10  0-1-2  2UNION OF INDIA, \nREPRESENTED BY THE STATUTOR...
# 11  0-1-3  THIS WRIT PETITION (CIVIL) HAVING COME UP FOR\...
# 12  0-2-0                       W.P.(C) No.970/2022\n: 3 :\n
# 13  0-2-1  [CR]\nN. NAGARESH, J.\n```````````````````````...
# 14  0-2-2  P4 and P6 orders of the District and\nState Co...
# 15  0-2-3  The petitioners  also pray to\ndeclare  that  ...
# 16  0-3-0  W.P.(C) No.970/2022\n: 4 :\n2.The petitioners ...
# 17  0-3-1                               There was no relief.
# 18  0-3-2  The complainant was sent to\nother opposite pa...
# 19  0-3-3  After the treatment by the opposite\nparties, ...
# 20  0-3-4  The\ncomplainant alleged that loss of eye sigh...
# 21  0-3-5  3.On receipt of notice, the petitioners filed ...
# 22  0-3-6  The District Commission\ndismissed  the I.A. a...
# 23  0-3-7  Ext.P5 Revision Petition filed by the petition...
# 24  0-4-0                       W.P.(C) No.970/2022\n: 5 :\n
# 25  0-4-1  4.The Senior Counsel assisted by the counsel f...
# 26  0-4-2  The learned Senior Counsel pointed out that th...
# 27  0-4-3  However, the health sector was removed from am...
# 28  0-4-4  The obvious reason is that\nthe  lawmakers  in...
# 29  0-4-5  5.The learned Senior Counsel argued that in In...
# 30  0-5-0  W.P.(C) No.970/2022\n: 6 :\nthe  purview  of  ...
# 31  0-5-1  In view of the law laid down\nby the Hon'ble A...
# 32  0-5-2  6.The  fact  that  'medical  profession/practi...
# 33  0-5-3  7.There are other factors that influenced the ...
# 34  0-5-4  Section 34 of the new Act has fixed the territ...
# 35  0-6-0  W.P.(C) No.970/2022\n: 7 :\nto  be  applied  t...
# 36  0-6-1  Compelling  the\nDoctors to leave their place ...
# 37  0-6-2  The lawmakers  were  convinced  about  the unf...
# 38  0-6-3  The  Consumer  Protection  Courts  do  not  ha...
# 39  0-6-4  Therefore,  when  the  intention  of  the  Leg...
# 40  0-6-5  8.I  have  heard  the  learned  Senior  Counse...
# 41  0-6-6  S. Gopakumaran Nair assisted by the counsel fo...
# 42  0-6-7  9.The argument of the petitioners is that a co...
# 43  0-7-0  W.P.(C) No.970/2022\n: 8 :\nservice  is  not  ...
# 44  0-7-1  The  question  whether  medical  negligence/\n...
# 45  0-7-2  10.In V.P. Shantha  (supra), the issue was con...
# 46  0-7-3  Section 2(1)(o) reads as follows: \n2(1)(o)"se...
# 47  0-7-4  The Hon’ble Apex Court held that services rend...
# 48  0-8-0  W.P.(C) No.970/2022\n: 9 :\ndiagnosis and trea...
# 49  0-8-1  11.The Act, 1986 was substituted by the Consum...
#
#                          metadata
# 0   {'pageID': '0', 'pdfID': '0'}
# 1   {'pageID': '0', 'pdfID': '0'}
# 2   {'pageID': '0', 'pdfID': '0'}
# 3   {'pageID': '0', 'pdfID': '0'}
# 4   {'pageID': '0', 'pdfID': '0'}
# 5   {'pageID': '0', 'pdfID': '0'}
# 6   {'pageID': '0', 'pdfID': '0'}
# 7   {'pageID': '0', 'pdfID': '0'}
# 8   {'pageID': '1', 'pdfID': '0'}
# 9   {'pageID': '1', 'pdfID': '0'}
# 10  {'pageID': '1', 'pdfID': '0'}
# 11  {'pageID': '1', 'pdfID': '0'}
# 12  {'pageID': '2', 'pdfID': '0'}
# 13  {'pageID': '2', 'pdfID': '0'}
# 14  {'pageID': '2', 'pdfID': '0'}
# 15  {'pageID': '2', 'pdfID': '0'}
# 16  {'pageID': '3', 'pdfID': '0'}
# 17  {'pageID': '3', 'pdfID': '0'}
# 18  {'pageID': '3', 'pdfID': '0'}
# 19  {'pageID': '3', 'pdfID': '0'}
# 20  {'pageID': '3', 'pdfID': '0'}
# 21  {'pageID': '3', 'pdfID': '0'}
# 22  {'pageID': '3', 'pdfID': '0'}
# 23  {'pageID': '3', 'pdfID': '0'}
# 24  {'pageID': '4', 'pdfID': '0'}
# 25  {'pageID': '4', 'pdfID': '0'}
# 26  {'pageID': '4', 'pdfID': '0'}
# 27  {'pageID': '4', 'pdfID': '0'}
# 28  {'pageID': '4', 'pdfID': '0'}
# 29  {'pageID': '4', 'pdfID': '0'}
# 30  {'pageID': '5', 'pdfID': '0'}
# 31  {'pageID': '5', 'pdfID': '0'}
# 32  {'pageID': '5', 'pdfID': '0'}
# 33  {'pageID': '5', 'pdfID': '0'}
# 34  {'pageID': '5', 'pdfID': '0'}
# 35  {'pageID': '6', 'pdfID': '0'}
# 36  {'pageID': '6', 'pdfID': '0'}
# 37  {'pageID': '6', 'pdfID': '0'}
# 38  {'pageID': '6', 'pdfID': '0'}
# 39  {'pageID': '6', 'pdfID': '0'}
# 40  {'pageID': '6', 'pdfID': '0'}
# 41  {'pageID': '6', 'pdfID': '0'}
# 42  {'pageID': '6', 'pdfID': '0'}
# 43  {'pageID': '7', 'pdfID': '0'}
# 44  {'pageID': '7', 'pdfID': '0'}
# 45  {'pageID': '7', 'pdfID': '0'}
# 46  {'pageID': '7', 'pdfID': '0'}
# 47  {'pageID': '7', 'pdfID': '0'}
# 48  {'pageID': '8', 'pdfID': '0'}
# 49  {'pageID': '8', 'pdfID': '0'}

# %% [markdown]
# EMBEDDINGS

# %%
import chromadb
from chromadb.config import Settings

# Create a new persistent client
client = chromadb.PersistentClient(path="../embeddings/example", settings=Settings(allow_reset=True))

# %%
# CAUTION CAUTION CAUTION Empties and completely resets the database. ⚠️ This is destructive and not reversible.
# client.reset() # Reset the database
# CAUTION CAUTION CAUTION Empties and completely resets the database. ⚠️ This is destructive and not reversible.

# %%
# Create a vector database
exampleDB = client.get_or_create_collection('exampleDB')
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[48], line 2
#       1 # Create a vector database
# ----> 2 exampleDB = client.get_or_create_collection('exampleDB')
#
# File ~/repos/kanoon/.venv/lib/python3.12/site-packages/chromadb/api/client.py:237, in Client.get_or_create_collection(self, name, metadata, embedding_function, data_loader)
#     227 @override
#     228 def get_or_create_collection(
#     229     self,
#    (...)
#     235     data_loader: Optional[DataLoader[Loadable]] = None,
#     236 ) -> Collection:
# --> 237     return self._server.get_or_create_collection(
#     238         name=name,
#     239         metadata=metadata,
#     240         embedding_function=embedding_function,
#     241         data_loader=data_loader,
#     242         tenant=self.tenant,
#     243         database=self.database,
#     244     )
#
# File ~/repos/kanoon/.venv/lib/python3.12/site-packages/chromadb/telemetry/opentelemetry/__init__.py:127, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     125 global tracer, granularity
#     126 if trace_granularity < granularity:
# --> 127     return f(*args, **kwargs)
#     128 if not tracer:
#     129     return f(*args, **kwargs)
#
# File ~/repos/kanoon/.venv/lib/python3.12/site-packages/chromadb/api/segment.py:217, in SegmentAPI.get_or_create_collection(self, name, metadata, embedding_function, data_loader, tenant, database)
#     202 @trace_method(
#     203     "SegmentAPI.get_or_create_collection", OpenTelemetryGranularity.OPERATION
#     204 )
#    (...)
#     215     database: str = DEFAULT_DATABASE,
#     216 ) -> Collection:
# --> 217     return self.create_collection(  # type: ignore
#     218         name=name,
#     219         metadata=metadata,
#     220         embedding_function=embedding_function,
#     221         data_loader=data_loader,
#     222         get_or_create=True,
#     223         tenant=tenant,
#     224         database=database,
#     225     )
#
# File ~/repos/kanoon/.venv/lib/python3.12/site-packages/chromadb/telemetry/opentelemetry/__init__.py:127, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     125 global tracer, granularity
#     126 if trace_granularity < granularity:
# --> 127     return f(*args, **kwargs)
#     128 if not tracer:
#     129     return f(*args, **kwargs)
#
# File ~/repos/kanoon/.venv/lib/python3.12/site-packages/chromadb/api/segment.py:167, in SegmentAPI.create_collection(self, name, metadata, embedding_function, data_loader, get_or_create, tenant, database)
#     163 check_index_name(name)
#     165 id = uuid4()
# --> 167 coll, created = self._sysdb.create_collection(
#     168     id=id,
#     169     name=name,
#     170     metadata=metadata,
#     171     dimension=None,
#     172     get_or_create=get_or_create,
#     173     tenant=tenant,
#     174     database=database,
#     175 )
#     177 if created:
#     178     segments = self._manager.create_segments(coll)
#
# File ~/repos/kanoon/.venv/lib/python3.12/site-packages/chromadb/telemetry/opentelemetry/__init__.py:127, in trace_method.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     125 global tracer, granularity
#     126 if trace_granularity < granularity:
# --> 127     return f(*args, **kwargs)
#     128 if not tracer:
#     129     return f(*args, **kwargs)
#
# File ~/repos/kanoon/.venv/lib/python3.12/site-packages/chromadb/db/mixins/sysdb.py:267, in SqlSysDB.create_collection(self, id, name, metadata, dimension, get_or_create, tenant, database)
#     265 sql, params = get_sql(insert_collection, self.parameter_format())
#     266 try:
# --> 267     cur.execute(sql, params)
#     268 except self.unique_constraint_error() as e:
#     269     raise UniqueConstraintError(
#     270         f"Collection {collection['id']} already exists"
#     271     ) from e
#
# OperationalError: attempt to write a readonly database

# %%
# exampleDB.add(
#     documents=documents,
#     metadatas=metadatas,
#     ids=ids
# )

# %%
results = exampleDB.query(
    query_texts=["Viction went through hell"],
    n_results=5
)

results
# Out:
# {'ids': [['0-3-1', '0-3-3', '0-7-1', '0-3-4', '0-10-7']],
#  'distances': [[1.3381223627503263,
#    1.5288106663427716,
#    1.5588837089660148,
#    1.6004951168959924,
#    1.620079943962757]],
#  'metadatas': [[{'pageID': '3', 'pdfID': '0'},
#    {'pageID': '3', 'pdfID': '0'},
#    {'pageID': '7', 'pdfID': '0'},
#    {'pageID': '3', 'pdfID': '0'},
#    {'pageID': '10', 'pdfID': '0'}]],
#  'embeddings': None,
#  'documents': [['There was no relief.',
#    'After the treatment by the opposite\nparties, the complainant lost the sight of her left eye.',
#    'The  question  whether  medical  negligence/\ndeficiency in medical services would fall within the ambit of\n‘service’ came up for consideration before the Hon’ble Apex\nCourt, in V.P. Shantha  (supra). \n',
#    'The\ncomplainant alleged that loss of eye sight was due to medical\nnegligence and sought for a compensation of ₹32,52,000/-. \n',
#    'The words “Medical Service” were not expressly']],
#  'uris': None,
#  'data': None}
